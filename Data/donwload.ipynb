# %%
# !pip install wget
# !python -m wget https://www.cs.rice.edu/~vo9/sbucaptions/sbu-captions-all.tar.gz
# !tar -xvzf sbu-captions-all.tar.gz
# Out:
# ...
#   Using cached wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=11553 sha256=d4ae7cb49c1fe455bb4ae7721e63611281fb670dc768a615bf4ad3703bd033e8
#   Stored in directory: c:\users\aaron\appdata\local\pip\cache\wheels\04\5f\3e\46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# ...
#
# Saved under sbu-captions-all.tar.gz
# x ./._sbu-captions-all.json
# x sbu-captions-all.json

# %%
# !img2dataset --url_list sbu-captions-all.json --input_format "json" --url_col "image_urls" --caption_col "captions" --output_format files --output_folder sbucaptions --processes_count 16 --thread_count 64 --image_size 256
# Out:
# Starting the downloading of this file
# Sharding file number 1 of 1 called d:/Rutgers/Grad Courses/Natural Language Processing/Final Project - MiniGLIDE/Data/sbu-captions-all.json
# File sharded in 100 shards
# ...
# worker  - success: 0.834 - failed to download: 0.166 - failed to resize: 0.000 - images per sec: 10 - count: 10000
# total   - success: 0.834 - failed to download: 0.166 - failed to resize: 0.000 - images per sec: 10 - count: 10000
# worker  - success: 0.831 - failed to download: 0.169 - failed to resize: 0.000 - images per sec: 10 - count: 10000
# total   - success: 0.833 - failed to download: 0.167 - failed to resize: 0.000 - images per sec: 20 - count: 20000
# worker  - success: 0.838 - failed to download: 0.162 - failed to resize: 0.000 - images per sec: 10 - count: 10000
# total   - success: 0.834 - failed to download: 0.166 - failed to resize: 0.000 - images per sec: 30 - count: 30000
# ...
